# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
f = open("/content/samplefile.txt", "r")

# %%
sentences = f.readlines()
sentences
f.close()

# %%
verbs = [[] for _ in sentences]
i=0
for sentence in sentences:
  print("Sentence",i+1,":", sentence)

  # Tokenize the sentence into words
  words = word_tokenize(sentence)

  # Identify the parts of speech for each word
  pos_tags = nltk.pos_tag(words)

  # Print the parts of speech
  for word,tag in pos_tags:
    print(word,"->",tag)

    # Save verbs
    if tag.startswith('VB'):
      verbs[i].append(word)
  i+=1
  print("\n\n")
# Out:
# Sentence 1 : The curious dog chased the red ball through the park.
#
# The -> DT
# curious -> JJ
# dog -> NN
# chased -> VBD
# the -> DT
# red -> JJ
# ball -> NN
# through -> IN
# the -> DT
# park -> NN
# . -> .
#
#
#
# Sentence 2 : Sarah enjoys baking delicious chocolate chip cookies on weekends.
#
# Sarah -> NNP
# enjoys -> VBZ
# baking -> VBG
# delicious -> JJ
# chocolate -> NN
# chip -> NN
# cookies -> NNS
# on -> IN
# weekends -> NNS
# . -> .
#
#
#
# Sentence 3 : Artificial intelligence is rapidly transforming many industries.
#
# Artificial -> JJ
# intelligence -> NN
# is -> VBZ
# rapidly -> RB
# transforming -> VBG
# many -> JJ
# industries -> NNS
# . -> .
#
#
#
# Sentence 4 : Despite the rain, the children played happily in puddles.
#
# Despite -> IN
# the -> DT
# rain -> NN
# , -> ,
# the -> DT
# children -> NNS
# played -> VBD
# happily -> RB
# in -> IN
# puddles -> NNS
# . -> .
#
#
#
# Sentence 5 : This new book explores the history of ancient civilizations.
#
# This -> DT
# new -> JJ
# book -> NN
# explores -> VBZ
# the -> DT
# history -> NN
# of -> IN
# ancient -> JJ
# civilizations -> NNS
# . -> .
#
#
#
# Sentence 6 : The concert was a huge success, with thousands of fans in attendance.
#
# The -> DT
# concert -> NN
# was -> VBD
# a -> DT
# huge -> JJ
# success -> NN
# , -> ,
# with -> IN
# thousands -> NNS
# of -> IN
# fans -> NNS
# in -> IN
# attendance -> NN
# . -> .
#
#
#
# Sentence 7 : John decided to learn a new language this year.
#
# John -> NNP
# decided -> VBD
# to -> TO
# learn -> VB
# a -> DT
# new -> JJ
# language -> NN
# this -> DT
# year -> NN
# . -> .
#
#
#
# Sentence 8 : Medical research is constantly striving to find cures for diseases.
#
# Medical -> JJ
# research -> NN
# is -> VBZ
# constantly -> RB
# striving -> VBG
# to -> TO
# find -> VB
# cures -> NNS
# for -> IN
# diseases -> NNS
# . -> .
#
#
#
# Sentence 9 : The aroma of freshly brewed coffee filled the air.
#
# The -> DT
# aroma -> NN
# of -> IN
# freshly -> JJ
# brewed -> VBN
# coffee -> NN
# filled -> VBD
# the -> DT
# air -> NN
# . -> .
#
#
#
# Sentence 10 : Recycling plastic bottles helps to conserve natural resources.
#
# Recycling -> VBG
# plastic -> NN
# bottles -> NNS
# helps -> VBZ
# to -> TO
# conserve -> VB
# natural -> JJ
# resources -> NNS
# . -> .
#
#
#
# Sentence 11 : The majestic mountains stood tall against the clear blue sky.
#
# The -> DT
# majestic -> JJ
# mountains -> NNS
# stood -> VBD
# tall -> JJ
# against -> IN
# the -> DT
# clear -> JJ
# blue -> NN
# sky -> NN
# . -> .
#
#
#
# Sentence 12 : The library is a treasure trove of knowledge waiting to be explored.
#
# The -> DT
# library -> NN
# is -> VBZ
# a -> DT
# treasure -> NN
# trove -> NN
# of -> IN
# knowledge -> NN
# waiting -> VBG
# to -> TO
# be -> VB
# explored -> VBN
# . -> .
#
#
#
# Sentence 13 : Taking a walk in nature is a great way to relax and de-stress.
#
# Taking -> VBG
# a -> DT
# walk -> NN
# in -> IN
# nature -> NN
# is -> VBZ
# a -> DT
# great -> JJ
# way -> NN
# to -> TO
# relax -> VB
# and -> CC
# de-stress -> NN
# . -> .
#
#
#
# Sentence 14 : Many people enjoy traveling to new and exciting destinations.
#
# Many -> JJ
# people -> NNS
# enjoy -> VBP
# traveling -> VBG
# to -> TO
# new -> JJ
# and -> CC
# exciting -> JJ
# destinations -> NNS
# . -> .
#
#
#
# Sentence 15 : Technology has made communication much faster and easier.
#
# Technology -> NN
# has -> VBZ
# made -> VBN
# communication -> NN
# much -> JJ
# faster -> JJR
# and -> CC
# easier -> JJR
# . -> .
#
#
#
# Sentence 16 : Learning to play a musical instrument can be a rewarding experience.
#
# Learning -> VBG
# to -> TO
# play -> VB
# a -> DT
# musical -> JJ
# instrument -> NN
# can -> MD
# be -> VB
# a -> DT
# rewarding -> JJ
# experience -> NN
# . -> .
#
#
#
# Sentence 17 : Protecting endangered species is crucial for maintaining biodiversity.
#
# Protecting -> VBG
# endangered -> VBN
# species -> NNS
# is -> VBZ
# crucial -> JJ
# for -> IN
# maintaining -> VBG
# biodiversity -> NN
# . -> .
#
#
#
# Sentence 18 : The internet has revolutionized the way we access information.
#
# The -> DT
# internet -> NN
# has -> VBZ
# revolutionized -> VBN
# the -> DT
# way -> NN
# we -> PRP
# access -> NN
# information -> NN
# . -> .
#
#
#
# Sentence 19 : Astronomy allows us to study the vast universe beyond our planet.
#
# Astronomy -> NNP
# allows -> VBZ
# us -> PRP
# to -> TO
# study -> VB
# the -> DT
# vast -> JJ
# universe -> JJ
# beyond -> IN
# our -> PRP$
# planet -> NN
# . -> .
#
#
#
# Sentence 20 : Ecotourism promotes sustainable travel practices.
#
# Ecotourism -> NN
# promotes -> VBZ
# sustainable -> JJ
# travel -> NN
# practices -> NNS
# . -> .
#
#
#
# Sentence 21 : A healthy diet is essential for maintaining good physical health.
#
# A -> DT
# healthy -> JJ
# diet -> NN
# is -> VBZ
# essential -> JJ
# for -> IN
# maintaining -> VBG
# good -> JJ
# physical -> JJ
# health -> NN
# . -> .
#
#
#
# Sentence 22 : Building strong relationships with others is important for emotional well-being.
#
# Building -> NN
# strong -> JJ
# relationships -> NNS
# with -> IN
# others -> NNS
# is -> VBZ
# important -> JJ
# for -> IN
# emotional -> JJ
# well-being -> NN
# . -> .
#
#
#
# Sentence 23 : Climate change is a major challenge facing our planet today.
#
# Climate -> NNP
# change -> NN
# is -> VBZ
# a -> DT
# major -> JJ
# challenge -> NN
# facing -> VBG
# our -> PRP$
# planet -> NN
# today -> NN
# . -> .
#
#
#
# Sentence 24 : Renewable energy sources like solar and wind power are becoming increasingly popular.
#
# Renewable -> JJ
# energy -> NN
# sources -> NNS
# like -> IN
# solar -> JJ
# and -> CC
# wind -> JJ
# power -> NN
# are -> VBP
# becoming -> VBG
# increasingly -> RB
# popular -> JJ
# . -> .
#
#
#
# Sentence 25 : Space exploration allows us to learn more about the origins of our universe.
#
# Space -> NNP
# exploration -> NN
# allows -> VBZ
# us -> PRP
# to -> TO
# learn -> VB
# more -> JJR
# about -> IN
# the -> DT
# origins -> NNS
# of -> IN
# our -> PRP$
# universe -> NN
# . -> .
#
#
#
# Sentence 26 : Volunteering your time to help others can be a rewarding experience.
#
# Volunteering -> VBG
# your -> PRP$
# time -> NN
# to -> TO
# help -> VB
# others -> NNS
# can -> MD
# be -> VB
# a -> DT
# rewarding -> JJ
# experience -> NN
# . -> .
#
#
#
# Sentence 27 : Critical thinking skills are essential for success in today's world.
#
# Critical -> JJ
# thinking -> NN
# skills -> NNS
# are -> VBP
# essential -> JJ
# for -> IN
# success -> NN
# in -> IN
# today -> NN
# 's -> POS
# world -> NN
# . -> .
#
#
#
# Sentence 28 : The power of imagination allows us to create and innovate.
#
# The -> DT
# power -> NN
# of -> IN
# imagination -> NN
# allows -> VBZ
# us -> PRP
# to -> TO
# create -> VB
# and -> CC
# innovate -> VB
# . -> .
#
#
#
# Sentence 29 : Developing a strong work ethic is important for achieving your goals.
#
# Developing -> VBG
# a -> DT
# strong -> JJ
# work -> NN
# ethic -> NN
# is -> VBZ
# important -> JJ
# for -> IN
# achieving -> VBG
# your -> PRP$
# goals -> NNS
# . -> .
#
#
#
# Sentence 30 : Education is the key to unlocking your full potential.
# Education -> NN
# is -> VBZ
# the -> DT
# key -> NN
# to -> TO
# unlocking -> VB
# your -> PRP$
# full -> JJ
# potential -> NN
# . -> .

# %%
# Identify synonyms and antonyms for each word
print("Synonyms and Antonymns for verbs in each sentence:\n")
i=0
for sentence in sentences:
  print("Sentence",i+1,":", sentence)
  pos_tags = nltk.pos_tag(verbs[i])
  for word,tag in pos_tags:
    print(word,"->",tag)
    synonyms = []
    antonyms = []
    for syn in wordnet.synsets(word):
      for lemma in syn.lemmas():
        synonyms.append(lemma.name())
        if lemma.antonyms():
          for antonym in lemma.antonyms():
            antonyms.append(antonym.name())

    # Print the synonyms and antonyms
    print("Synonyms:",set(synonyms))
    print("Antonyms:", set(antonyms) if antonyms else "None")
    print()
  print("\n\n")
  i+=1
# Out:
# Synonyms and Antonymns for verbs in each sentence:
#
# Sentence 1 : The curious dog chased the red ball through the park.
#
# chased -> VBN
# Synonyms: {'tail', 'chamfer', 'tag', 'chase_after', 'pursued', 'chase', 'give_chase', 'trail', 'dog', 'go_after', 'chased', 'furrow', 'track'}
# Antonyms: None
#
#
#
#
# Sentence 2 : Sarah enjoys baking delicious chocolate chip cookies on weekends.
#
# enjoys -> NNS
# Synonyms: {'love', 'savour', 'bask', 'savor', 'relish', 'enjoy', 'delight', 'revel'}
# Antonyms: {'suffer'}
#
# baking -> VBG
# Synonyms: {'baking', 'baking_hot', 'broil', 'bake'}
# Antonyms: None
#
#
#
#
# Sentence 3 : Artificial intelligence is rapidly transforming many industries.
#
# is -> VBZ
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'follow', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
# transforming -> VBG
# Synonyms: {'transubstantiate', 'transmute', 'translate', 'metamorphose', 'transform'}
# Antonyms: None
#
#
#
#
# Sentence 4 : Despite the rain, the children played happily in puddles.
#
# played -> NNS
# Synonyms: {'represent', 'played', 'act_as', 'bet', 'make_for', 'wreak', 'wager', 'fiddle', 'playact', 'recreate', 'encounter', 'toy', 'diddle', 'work', 'trifle', 'bring', 'take_on', 'spiel', 'flirt', 'run', 'meet', 'act', 'dally', 'roleplay', 'play'}
# Antonyms: None
#
#
#
#
# Sentence 5 : This new book explores the history of ancient civilizations.
#
# explores -> NNS
# Synonyms: {'research', 'search', 'explore'}
# Antonyms: None
#
#
#
#
# Sentence 6 : The concert was a huge success, with thousands of fans in attendance.
#
# was -> VBD
# Synonyms: {'comprise', 'embody', 'cost', 'WA', 'be', 'Washington', 'follow', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute', 'Evergreen_State'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 7 : John decided to learn a new language this year.
#
# decided -> VBD
# Synonyms: {'distinct', 'decide', 'decided', "make_up_one's_mind", 'settle', 'determine', 'resolve', 'adjudicate'}
# Antonyms: None
#
# learn -> NN
# Synonyms: {'larn', 'check', 'instruct', 'pick_up', 'ascertain', 'con', 'see', 'discover', 'hear', 'learn', 'read', 'memorize', 'get_a_line', 'get_word', 'memorise', 'acquire', 'teach', 'find_out', 'get_wind', 'take', 'determine', 'study', 'watch'}
# Antonyms: None
#
#
#
#
# Sentence 8 : Medical research is constantly striving to find cures for diseases.
#
# is -> VBZ
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'follow', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
# striving -> VBG
# Synonyms: {'endeavour', 'nisus', 'pains', 'striving', 'strive', 'strain', 'endeavor', 'reach'}
# Antonyms: None
#
# find -> VB
# Synonyms: {'receive', 'witness', 'regain', 'bump', 'uncovering', 'observe', 'ascertain', 'notice', 'happen', 'get_hold', 'discovery', 'line_up', 'see', 'detect', 'recover', 'discover', 'incur', 'chance', 'breakthrough', 'retrieve', 'encounter', 'get', 'rule', 'feel', 'find_out', 'obtain', 'find', 'find_oneself', 'come_up', 'determine'}
# Antonyms: {'lose'}
#
#
#
#
# Sentence 9 : The aroma of freshly brewed coffee filled the air.
#
# brewed -> VBN
# Synonyms: {'brew'}
# Antonyms: None
#
# filled -> VBD
# Synonyms: {'replete', 'occupy', 'make_full', 'fulfill', 'meet', 'filled', 'take', 'satisfy', 'fill', 'sate', 'fulfil', 'fill_up', 'satiate'}
# Antonyms: {'empty', 'unfilled'}
#
#
#
#
# Sentence 10 : Recycling plastic bottles helps to conserve natural resources.
#
# Recycling -> VBG
# Synonyms: {'reprocess', 'recycling', 'recycle', 'reuse'}
# Antonyms: None
#
# helps -> VBZ
# Synonyms: {'help_oneself', 'assist', 'facilitate', 'serve', 'helper', 'avail', 'help', 'assistance', 'aid', 'assistant', 'supporter', 'service'}
# Antonyms: None
#
# conserve -> VB
# Synonyms: {'keep_up', 'maintain', 'economise', 'economize', 'preserves', 'husband', 'preserve', 'conserves', 'conserve'}
# Antonyms: {'waste'}
#
#
#
#
# Sentence 11 : The majestic mountains stood tall against the clear blue sky.
#
# stood -> NN
# Synonyms: {'remain_firm', 'place_upright', 'abide', 'tolerate', 'digest', 'stand', 'resist', 'stomach', 'bear', 'support', 'stand_up', 'put_up', 'fend', 'brook', 'stick_out', 'suffer', 'endure'}
# Antonyms: {'lie', 'yield', 'sit'}
#
#
#
#
# Sentence 12 : The library is a treasure trove of knowledge waiting to be explored.
#
# is -> VBZ
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'follow', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
# waiting -> VBG
# Synonyms: {'look', 'hold_off', 'waitress', 'wait', 'hold_back', 'expect', 'waiting', 'ready_and_waiting', 'await'}
# Antonyms: None
#
# be -> VB
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'atomic_number_4', 'make_up', 'follow', 'represent', 'glucinium', 'equal', 'exist', 'personify', 'constitute', 'Be', 'live', 'beryllium'}
# Antonyms: {'differ'}
#
# explored -> VBN
# Synonyms: {'research', 'search', 'explore'}
# Antonyms: None
#
#
#
#
# Sentence 13 : Taking a walk in nature is a great way to relax and de-stress.
#
# Taking -> VBG
# Synonyms: {'claim', 'occupy', 'convey', 'rent', 'postulate', 'subscribe', 'take_in', 'withdraw', 'contract', 'engage', 'taking', 'require', 'charter', 'ingest', 'study', 'necessitate', 'demand', 'film', 'hold', 'select', 'conduct', 'drive', 'carry', 'look_at', 'assume', 'call_for', 'take_away', 'need', 'read', 'learn', 'use_up', 'submit', 'pick_out', 'consume', 'hire', 'pack', 'remove', 'take_up', 'lease', 'contain', 'train', 'involve', 'acquire', 'pickings', 'admit', 'get_hold_of', 'ask', 'take_aim', 'have', 'get', 'deal', 'guide', 'accept', 'fetching', 'exact', 'lead', 'make', 'direct', 'take_on', 'bring', 'winning', 'take', 'consider', 'aim', 'subscribe_to', 'adopt', 'shoot', 'fill', 'strike', 'choose'}
# Antonyms: {'abstain', 'give', 'disclaim', 'obviate', 'refuse'}
#
# is -> VBZ
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'follow', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
# relax -> NN
# Synonyms: {'slow_down', 'loose', 'decompress', 'slacken', 'slack_up', 'unlax', 'slack', 'relax', 'unstrain', 'unbend', 'loosen', 'make_relaxed', 'loosen_up', 'unwind'}
# Antonyms: {'strain', 'stiffen', 'tense'}
#
#
#
#
# Sentence 14 : Many people enjoy traveling to new and exciting destinations.
#
# enjoy -> NN
# Synonyms: {'love', 'savour', 'bask', 'savor', 'relish', 'enjoy', 'delight', 'revel'}
# Antonyms: {'suffer'}
#
# traveling -> VBG
# Synonyms: {'go', 'trip', 'travel', 'move', 'locomote', 'traveling', 'move_around', 'journey', 'travelling', 'jaunt'}
# Antonyms: {'stay_in_place'}
#
#
#
#
# Sentence 15 : Technology has made communication much faster and easier.
#
# has -> VBZ
# Synonyms: {'receive', 'let', 'give', 'take_in', 'bear', 'experience', 'ingest', 'deliver', 'hold', 'cause', 'have_got', 'HA', 'hour_angle', 'consume', 'suffer', 'throw', 'own', 'feature', 'sustain', 'get', 'give_birth', 'have', 'accept', 'birth', 'make', 'induce', 'stimulate', 'possess', 'take'}
# Antonyms: {'abstain', 'refuse', 'lack'}
#
# made -> VBN
# Synonyms: {'give', 'wee-wee', 'name', 'bring_in', 'take_in', 'make_water', 'ca-ca', 'seduce', 'shit', 'pee-pee', 'stool', 'establish', 'create', 'progress_to', 'hold', 'ready', 'lay_down', 'cook', 'relieve_oneself', 'take_a_leak', 'cause', 'arrive_at', 'make_up', 'crap', 'pass_water', 'pull_in', 'pee', 'realise', 'constitute', 'draw', 'reach', 'earn', 'throw', 'defecate', 'attain', 'wee', 'piddle', 'get_to', 'urinate', 'score', 'nominate', 'micturate', 'get', 'prepare', 'pretend', 'gain', 'have', 'construct', 'fix', 'work', 'made', 'take_a_crap', 'make', 'induce', 'stimulate', 'puddle', 'form', 'spend_a_penny', 'do', 'produce', 'hit', 'realize', 'build', 'take', 'make_believe', 'clear', 'piss', 'take_a_shit'}
# Antonyms: {'unmake', 'break', 'unmade'}
#
#
#
#
# Sentence 16 : Learning to play a musical instrument can be a rewarding experience.
#
# Learning -> VBG
# Synonyms: {'larn', 'check', 'instruct', 'learning', 'pick_up', 'ascertain', 'con', 'acquisition', 'see', 'discover', 'hear', 'erudition', 'learn', 'read', 'scholarship', 'memorize', 'get_a_line', 'get_word', 'encyclopedism', 'learnedness', 'memorise', 'acquire', 'teach', 'encyclopaedism', 'eruditeness', 'find_out', 'get_wind', 'take', 'determine', 'study', 'watch'}
# Antonyms: None
#
# play -> NN
# Synonyms: {'gambol', 'bid', 'gaming', 'gambling', 'dramatic_play', 'represent', 'maneuver', 'romp', 'swordplay', 'act_as', "child's_play", 'sport', 'turn', 'bet', 'period_of_play', 'frolic', 'make_for', 'wreak', 'wager', 'fiddle', 'drama', 'playact', 'recreate', 'encounter', 'caper', 'toy', 'play', 'playing_period', 'diddle', 'work', 'manoeuvre', 'free_rein', 'trifle', 'bring', 'take_on', 'fun', 'spiel', 'flirt', 'run', 'meet', 'act', 'dally', 'roleplay', 'shimmer', 'looseness'}
# Antonyms: {'tightness'}
#
# be -> VB
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'atomic_number_4', 'make_up', 'follow', 'represent', 'glucinium', 'equal', 'exist', 'personify', 'constitute', 'Be', 'live', 'beryllium'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 17 : Protecting endangered species is crucial for maintaining biodiversity.
#
# Protecting -> VBG
# Synonyms: {'protect', 'protecting'}
# Antonyms: None
#
# endangered -> VBN
# Synonyms: {'expose', 'menace', 'jeopardise', 'threaten', 'endanger', 'peril', 'endangered', 'scupper', 'imperil', 'queer', 'jeopardize'}
# Antonyms: None
#
# is -> VBZ
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'follow', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
# maintaining -> VBG
# Synonyms: {'hold', 'keep_up', 'keep', 'defend', 'maintain', 'sustain', 'asseverate', 'wield', 'uphold', 'observe', 'assert', 'exert', 'preserve', 'conserve'}
# Antonyms: None
#
#
#
#
# Sentence 18 : The internet has revolutionized the way we access information.
#
# has -> VBZ
# Synonyms: {'receive', 'let', 'give', 'take_in', 'bear', 'experience', 'ingest', 'deliver', 'hold', 'cause', 'have_got', 'HA', 'hour_angle', 'consume', 'suffer', 'throw', 'own', 'feature', 'sustain', 'get', 'give_birth', 'have', 'accept', 'birth', 'make', 'induce', 'stimulate', 'possess', 'take'}
# Antonyms: {'abstain', 'refuse', 'lack'}
#
# revolutionized -> VBN
# Synonyms: {'inspire', 'overturn', 'revolutionise', 'revolutionize'}
# Antonyms: None
#
#
#
#
# Sentence 19 : Astronomy allows us to study the vast universe beyond our planet.
#
# allows -> NNS
# Synonyms: {'let', 'permit', 'grant', 'countenance', 'tolerate', 'leave', 'allow_for', 'reserve', 'provide', 'admit', 'appropriate', 'earmark', 'allow', 'set_aside', 'give_up', 'take_into_account'}
# Antonyms: {'disallow', 'deny', 'forbid', 'prevent'}
#
# study -> NN
# Synonyms: {'contemplate', 'field', 'examine', 'subject_area', 'study', 'cogitation', 'discipline', 'canvass', 'learn', 'read', 'survey', 'hit_the_books', 'canvas', 'work', 'meditate', 'report', 'bailiwick', 'written_report', 'analyze', 'subject_field', 'field_of_study', 'sketch', 'consider', 'take', 'analyse', 'subject'}
# Antonyms: None
#
#
#
#
# Sentence 20 : Ecotourism promotes sustainable travel practices.
#
# promotes -> NNS
# Synonyms: {'boost', 'upgrade', 'push', 'kick_upstairs', 'advertise', 'promote', 'further', 'advertize', 'advance', 'elevate', 'raise', 'encourage'}
# Antonyms: {'demote'}
#
#
#
#
# Sentence 21 : A healthy diet is essential for maintaining good physical health.
#
# is -> VBZ
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'follow', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
# maintaining -> VBG
# Synonyms: {'hold', 'keep_up', 'keep', 'defend', 'maintain', 'sustain', 'asseverate', 'wield', 'uphold', 'observe', 'assert', 'exert', 'preserve', 'conserve'}
# Antonyms: None
#
#
#
#
# Sentence 22 : Building strong relationships with others is important for emotional well-being.
#
# is -> VBZ
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'follow', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 23 : Climate change is a major challenge facing our planet today.
#
# is -> VBZ
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'follow', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
# facing -> VBG
# Synonyms: {'face', 'look', 'present', 'cladding', 'lining', 'front', 'confront', 'facing', 'veneer', 'face_up'}
# Antonyms: {'back', 'avoid'}
#
#
#
#
# Sentence 24 : Renewable energy sources like solar and wind power are becoming increasingly popular.
#
# are -> VBP
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'are', 'follow', 'ar', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
# becoming -> VBG
# Synonyms: {'suit', 'go', 'becoming', 'seemly', 'become', 'turn', 'comely', 'get', 'decent', 'comme_il_faut', 'decorous'}
# Antonyms: None
#
#
#
#
# Sentence 25 : Space exploration allows us to learn more about the origins of our universe.
#
# allows -> NNS
# Synonyms: {'let', 'permit', 'grant', 'countenance', 'tolerate', 'leave', 'allow_for', 'reserve', 'provide', 'admit', 'appropriate', 'earmark', 'allow', 'set_aside', 'give_up', 'take_into_account'}
# Antonyms: {'disallow', 'deny', 'forbid', 'prevent'}
#
# learn -> VBP
# Synonyms: {'larn', 'check', 'instruct', 'pick_up', 'ascertain', 'con', 'see', 'discover', 'hear', 'learn', 'read', 'memorize', 'get_a_line', 'get_word', 'memorise', 'acquire', 'teach', 'find_out', 'get_wind', 'take', 'determine', 'study', 'watch'}
# Antonyms: None
#
#
#
#
# Sentence 26 : Volunteering your time to help others can be a rewarding experience.
#
# Volunteering -> VBG
# Synonyms: {'offer', 'volunteer'}
# Antonyms: None
#
# help -> NN
# Synonyms: {'help_oneself', 'assist', 'facilitate', 'serve', 'helper', 'avail', 'help', 'assistance', 'aid', 'assistant', 'supporter', 'service'}
# Antonyms: None
#
# be -> VB
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'atomic_number_4', 'make_up', 'follow', 'represent', 'glucinium', 'equal', 'exist', 'personify', 'constitute', 'Be', 'live', 'beryllium'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 27 : Critical thinking skills are essential for success in today's world.
#
# are -> VBP
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'are', 'follow', 'ar', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 28 : The power of imagination allows us to create and innovate.
#
# allows -> NNS
# Synonyms: {'let', 'permit', 'grant', 'countenance', 'tolerate', 'leave', 'allow_for', 'reserve', 'provide', 'admit', 'appropriate', 'earmark', 'allow', 'set_aside', 'give_up', 'take_into_account'}
# Antonyms: {'disallow', 'deny', 'forbid', 'prevent'}
#
# create -> VBP
# Synonyms: {'make', 'create', 'produce'}
# Antonyms: None
#
# innovate -> NN
# Synonyms: {'innovate', 'introduce'}
# Antonyms: None
#
#
#
#
# Sentence 29 : Developing a strong work ethic is important for achieving your goals.
#
# Developing -> VBG
# Synonyms: {'modernise', 'uprise', 'spring_up', 'modernize', 'educate', 'make_grow', 'arise', 'evolve', 'grow', 'development', 'rise', 'train', 'build_up', 'germinate', 'acquire', 'get', 'originate', 'prepare', 'recrudesce', 'developing', 'produce', 'develop', 'underdeveloped', 'break', 'explicate', 'formulate'}
# Antonyms: None
#
# is -> VBZ
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'follow', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
# achieving -> VBG
# Synonyms: {'attain', 'accomplish', 'reach', 'achieve'}
# Antonyms: None
#
#
#
#
# Sentence 30 : Education is the key to unlocking your full potential.
# is -> VBZ
# Synonyms: {'comprise', 'embody', 'cost', 'be', 'follow', 'make_up', 'represent', 'live', 'equal', 'exist', 'personify', 'constitute'}
# Antonyms: {'differ'}
#
# unlocking -> VBG
# Synonyms: {'unlock'}
# Antonyms: {'lock'}
